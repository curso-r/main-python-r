# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Introdução ao pandas
#
# ### Séries

# %%
# uma série é um vetor unidimensional contendo uma sequência de valores
# e um vetor de rótulos associados - chamado de índice!
x = pd.Series([12,13,1])

# %%
x
# Out:
# 0    12
# 1    13
# 2     1
# dtype: int64

# %%
print(type(x.values))
x.values
# Out:
# <class 'numpy.ndarray'>
# array([12, 13,  1])

# %%
x.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
x = pd.Series([1,2,3], index = ["a", "b", "c"])
x
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
x[x>1]
# Out:
# b    2
# c    3
# dtype: int64

# %% [markdown]
# ### DataFrame

# %%
# DataFrame's representam tabelas retangulares.
# São conjuntos de séries que compartilham o **mesmo** índice
df = pd.DataFrame({
    "hello": [1,2,3],
    "bye": [4,5,6]
})

# %%
df
# Out:
#    hello  bye
# 0      1    4
# 1      2    5
# 2      3    6

# %%
x = pd.Series([1,2,3], index = ["a", "b", "c"])
y = pd.Series([1,2,3], index = ["x", "y", "z"])
df = pd.DataFrame({"col1": x, "col2": y})

# %%
# isso é meio inesperado vindo do Rm - em geral as funções do tidyverse 
# descartam os 'índices' ou nomes dos vetores.
df
# Out:
#    col1  col2
# a   1.0   NaN
# b   2.0   NaN
# c   3.0   NaN
# x   NaN   1.0
# y   NaN   2.0
# z   NaN   3.0

# %% [markdown]
# ### Importação dos dados
#
# #### Lendo arquivos

# %%
df = pd.read_csv("../dados/imdb.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28490 entries, 0 to 28489
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id_filme              28490 non-null  object
#  1   titulo                28490 non-null  object
#  2   ano                   28489 non-null  float64
#  3   data_lancamento       28490 non-null  object
#  4   generos               28490 non-null  object
#  5   duracao               28490 non-null  int64
#  6   pais                  28490 non-null  object
#  7   idioma                28146 non-null  object
#  8   orcamento             10470 non-null  float64
#  9   receita               7698 non-null   float64
#  10  receita_eua           7556 non-null   float64
#  11  nota_imdb             28490 non-null  float64
#  12  num_avaliacoes        28490 non-null  int64
#  13  direcao               28457 non-null  object
#  14  roteiro               28289 non-null  object
#  15  producao              27332 non-null  object
#  16  elenco                28464 non-null  object
#  17  descricao             28418 non-null  object
#  18  num_criticas_publico  28186 non-null  float64
#  19  num_criticas_critica  26618 non-null  float64
# dtypes: float64(7), int64(2), object(11)
# memory usage: 4.3+ MB

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 8.7 MB/s eta 0:00:00
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.10

# %%
df = pd.read_excel("../dados/imdb.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28490 entries, 0 to 28489
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id_filme              28490 non-null  object
#  1   titulo                28490 non-null  object
#  2   ano                   28489 non-null  float64
#  3   data_lancamento       28490 non-null  object
#  4   generos               28490 non-null  object
#  5   duracao               28490 non-null  int64
#  6   pais                  28490 non-null  object
#  7   idioma                28146 non-null  object
#  8   orcamento             10470 non-null  float64
#  9   receita               7698 non-null   float64
#  10  receita_eua           7556 non-null   float64
#  11  nota_imdb             28490 non-null  float64
#  12  num_avaliacoes        28490 non-null  int64
#  13  direcao               28457 non-null  object
#  14  roteiro               28289 non-null  object
#  15  producao              27332 non-null  object
#  16  elenco                28464 non-null  object
#  17  descricao             28418 non-null  object
#  18  num_criticas_publico  28186 non-null  float64
#  19  num_criticas_critica  26618 non-null  float64
# dtypes: float64(7), int64(2), object(11)
# memory usage: 4.3+ MB

# %%
# é possível ler de muitos outros formatos. veja por exemplo a tabela aqui:
# https://wesmckinney.com/book/accessing-data.html#io_flat_files

# %%
# Exercício:
# Carregue os dados provenientes do arquivo dados/imdb.sas7bdat

# %% [markdown]
# #### Escrevendo

# %%
df.to_csv("../dados/x.csv", index=False)

# %%
df.to_pickle("../dados/x.pickle")

# %% [markdown]
# ### Manipulação de dados

# %%
# vamos pensar em manipulação de dados fazendo um paralelo com o dplyr.
# dplyr: 6 verbos principais
# select()    # seleciona colunas do data.frame
# arrange()   # reordena as linhas do data.frame
# filter()    # filtra linhas do data.frame
# mutate()    # cria novas colunas no data.frame (ou atualiza as colunas existentes)
# summarise() + group_by() # sumariza o data.frame
# left_join   # junta dois data.frames

# %% [markdown]
# #### select

# %%
df = pd.read_csv("../dados/imdb.csv")

# %%
df[["titulo"]]
# Out:
#                           titulo
# 0                       Prestige
# 1                       Nob Hill
# 2                      The Shade
# 3      Viewer Discretion Advised
# 4                 Broadcast News
# ...                          ...
# 28485    Jumanji: The Next Level
# 28486      Monster on the Campus
# 28487                   The Ward
# 28488            A Game of Death
# 28489                    Swimfan
#
# [28490 rows x 1 columns]

# %%
# o filter atua nos índices do DataFrame, podendo ser o índice das
# linhas ou colunas. O padrão é pegar pelas colunas.
df.filter(["titulo"])
# Out:
#                           titulo
# 0                       Prestige
# 1                       Nob Hill
# 2                      The Shade
# 3      Viewer Discretion Advised
# 4                 Broadcast News
# ...                          ...
# 28485    Jumanji: The Next Level
# 28486      Monster on the Campus
# 28487                   The Ward
# 28488            A Game of Death
# 28489                    Swimfan
#
# [28490 rows x 1 columns]

# %%
df.filter(["titulo", "ano"])
# Out:
#                           titulo     ano
# 0                       Prestige  1931.0
# 1                       Nob Hill  1945.0
# 2                      The Shade  1999.0
# 3      Viewer Discretion Advised  1998.0
# 4                 Broadcast News  1987.0
# ...                          ...     ...
# 28485    Jumanji: The Next Level  2019.0
# 28486      Monster on the Campus  1958.0
# 28487                   The Ward  2010.0
# 28488            A Game of Death  1945.0
# 28489                    Swimfan  2002.0
#
# [28490 rows x 2 columns]

# %%
# Ao contrário do dplyr, não dá para remover colunas com o filter.
# para isso vc pode usar a drop
df.drop(["ano"], axis = "columns")
# Out:
#         id_filme                     titulo data_lancamento  \
# 0      tt0023352                   Prestige      1932-01-22
# 1      tt0037946                   Nob Hill      1945-11-15
# 2      tt0216204                  The Shade      2000-03-01
# 3      tt0171889  Viewer Discretion Advised      2012-05-01
# 4      tt0092699             Broadcast News      1988-04-01
# ...          ...                        ...             ...
# 28485  tt7975244    Jumanji: The Next Level      2019-12-25
# 28486  tt0051948      Monster on the Campus      1958-12-17
# 28487  tt1369706                   The Ward      2011-04-01
# 28488  tt0038549            A Game of Death      1946-06-07
# 28489  tt0283026                    Swimfan      2003-05-30
#
#                          generos  duracao pais  \
# 0               Adventure, Drama       71  USA
# 1                 Drama, Musical       95  USA
# 2                          Drama       83  USA
# 3                 Comedy, Horror      105  USA
# 4         Comedy, Drama, Romance      133  USA
# ...                          ...      ...  ...
# 28485  Action, Adventure, Comedy      123  USA
# 28486             Horror, Sci-Fi       77  USA
# 28487  Horror, Mystery, Thriller       89  USA
# 28488                  Adventure       72  USA
# 28489            Drama, Thriller       85  USA
#
#                                  idioma    orcamento      receita  \
# 0                               English          NaN          NaN
# 1                               English          NaN          NaN
# 2                               English     400000.0          NaN
# 3                               English          NaN          NaN
# 4      English, Spanish, French, German   20000000.0   67331309.0
# ...                                 ...          ...          ...
# 28485                           English  125000000.0  796575993.0
# 28486                           English          NaN          NaN
# 28487                           English   10000000.0    5343820.0
# 28488                           English          NaN          NaN
# 28489                           English   10000000.0   34411240.0
#
#        receita_eua  nota_imdb  num_avaliacoes                         direcao  \
# 0              NaN        5.7             240                     Tay Garnett
# 1              NaN        6.3             246                  Henry Hathaway
# 2              NaN        7.1             102                 Raphaël Nadjari
# 3              NaN        3.4             111  Eddie Beverly Jr., Tommy Blaze
# 4       51249404.0        7.2           26257                 James L. Brooks
# ...            ...        ...             ...                             ...
# 28485  316831246.0        6.7          168698                     Jake Kasdan
# 28486          NaN        5.8            1517                     Jack Arnold
# 28487          NaN        5.6           39789                  John Carpenter
# 28488          NaN        5.8             302                     Robert Wise
# 28489   28564995.0        5.1           18771                     John Polson
#
#                                   roteiro  \
# 0               Harry Hervey, Tay Garnett
# 1      Wanda Tuchock, Norman Reilly Raine
# 2      Fyodor Dostoevsky, Raphaël Nadjari
# 3              Tommy Blaze, Philip Morton
# 4                         James L. Brooks
# ...                                   ...
# 28485           Jake Kasdan, Jeff Pinkner
# 28486                        David Duncan
# 28487  Michael Rasmussen, Shawn Rasmussen
# 28488     Richard Connell, Norman Houston
# 28489  Charles F. Bohl, Phillip Schneider
#
#                                     producao  \
# 0                         RKO Pathé Pictures
# 1                      Twentieth Century Fox
# 2                                   Filmaker
# 3                        Troma Entertainment
# 4                             Amercent Films
# ...                                      ...
# 28485               Matt Tolmach Productions
# 28486  Universal International Pictures (UI)
# 28487               FilmNation Entertainment
# 28488                     RKO Radio Pictures
# 28489                  Twentieth Century Fox
#
#                                                   elenco  \
# 0      Ann Harding, Adolphe Menjou, Melvyn Douglas, I...
# 1      George Raft, Joan Bennett, Vivian Blaine, Pegg...
# 2      Richard Edson, Lorie Marino, Jeff Ware, Barbar...
# 3      Ken Donovan, Philip Morton, Caroline Jett, Tom...
# 4      William Hurt, Albert Brooks, Holly Hunter, Rob...
# ...                                                  ...
# 28485  Dwayne Johnson, Kevin Hart, Jack Black, Karen ...
# 28486  Arthur Franz, Joanna Moore, Judson Pratt, Nanc...
# 28487  Amber Heard, Mamie Gummer, Danielle Panabaker,...
# 28488  John Loder, Audrey Long, Edgar Barrier, Russel...
# 28489  Jesse Bradford, Erika Christensen, Shiri Apple...
#
#                                                descricao  \
# 0      A woman travels to a French penal colony in In...
# 1      The owner of a San Francisco saloon yearns to ...
# 2                                                    NaN
# 3      Ted Smith becomes trapped in the TV shows he w...
# 4      Take two rival television reporters: one hands...
# ...                                                  ...
# 28485  In Jumanji: The Next Level, the gang is back b...
# 28486  The blood of a primitive fish exposed to gamma...
# 28487  An institutionalized young woman becomes terro...
# 28488  A remake of Richard Connell's famous short sto...
# 28489  A high school senior with a promising swimming...
#
#        num_criticas_publico  num_criticas_critica
# 0                      12.0                   2.0
# 1                      11.0                   2.0
# 2                       1.0                   1.0
# 3                       5.0                   3.0
# 4                     142.0                  62.0
# ...                     ...                   ...
# 28485                 940.0                 241.0
# 28486                  49.0                  38.0
# 28487                 190.0                 263.0
# 28488                  11.0                  10.0
# 28489                 216.0                  88.0
#
# [28490 rows x 19 columns]

# %%
# como não tem non-standard evaluation, vc sempre pode colocar
# o nome numa lista e depois filtrar.
colunas = ["titulo", "ano"]
df.filter(colunas)
# Out:
#                           titulo     ano
# 0                       Prestige  1931.0
# 1                       Nob Hill  1945.0
# 2                      The Shade  1999.0
# 3      Viewer Discretion Advised  1998.0
# 4                 Broadcast News  1987.0
# ...                          ...     ...
# 28485    Jumanji: The Next Level  2019.0
# 28486      Monster on the Campus  1958.0
# 28487                   The Ward  2010.0
# 28488            A Game of Death  1945.0
# 28489                    Swimfan  2002.0
#
# [28490 rows x 2 columns]

# %% [markdown]
# #### arrange

# %%
df.sort_values(["ano"]).filter(["ano"])
# Out:
#           ano
# 12371  1894.0
# 8008   1912.0
# 18843  1912.0
# 20242  1913.0
# 3723   1914.0
# ...       ...
# 26345  2020.0
# 14065  2020.0
# 7813   2020.0
# 5659   2020.0
# 3537      NaN
#
# [28490 rows x 1 columns]

# %%
df.sort_values(["ano"], ascending = False).filter(["ano"])
# Out:
#           ano
# 28006  2020.0
# 18413  2020.0
# 15465  2020.0
# 19622  2020.0
# 3430   2020.0
# ...       ...
# 20242  1913.0
# 18843  1912.0
# 8008   1912.0
# 12371  1894.0
# 3537      NaN
#
# [28490 rows x 1 columns]

# %% [markdown]
# #### filter

# %%
df.query("ano == 2020") # meio esquisito pq a condição está entre aspas...
# Out:
#        id_filme                                             titulo     ano  \
# 238   tt8430598                                            Shirley  2020.0
# 301   tt7713068  Birds of Prey: And the Fantabulous Emancipatio...  2020.0
# 491  tt12158538                                          Cry Havoc  2020.0
#
#     data_lancamento                     generos  duracao pais  \
# 238      2020-06-05  Biography, Drama, Thriller      107  USA
# 301      2020-02-06    Action, Adventure, Crime      109  USA
# 491      2020-05-05                      Horror       85  USA
#
#                idioma   orcamento      receita  receita_eua  nota_imdb  \
# 238           English         NaN      75911.0          NaN        6.2
# 301  English, Chinese  84500000.0  201858461.0   84158461.0        6.1
# 491           English   4000000.0          NaN          NaN        3.2
#
#      num_avaliacoes           direcao                             roteiro  \
# 238            4612  Josephine Decker  Sarah Gubbins, Susan Scarf Merrell
# 301          137373         Cathy Yan         Christina Hodson, Paul Dini
# 491             136        Rene Perez                          Rene Perez
#
#                           producao  \
# 238  Los Angeles Media Fund (LAMF)
# 301        Clubhouse Pictures (II)
# 491           Samera Entertainment
#
#                                                 elenco  \
# 238  Elisabeth Moss, Odessa Young, Michael Stuhlbar...
# 301  Margot Robbie, Rosie Perez, Mary Elizabeth Win...
# 491  J.D. Angstadt, Robert Bronzi, Spring Inés Peña...
#
#                                              descricao  num_criticas_publico  \
# 238  A famous horror writer finds inspiration for h...                  75.0
# 301  After splitting with the Joker, Harley Quinn j...                2222.0
# 491  A rogue police officer takes on a serial kille...                   9.0
#
#      num_criticas_critica
# 238                  98.0
# 301                 372.0
# 491                  23.0

# %%
df[df["ano"] == 2020] # muito parecido com base R
# Out:
#          id_filme                                             titulo     ano  \
# 238     tt8430598                                            Shirley  2020.0
# 301     tt7713068  Birds of Prey: And the Fantabulous Emancipatio...  2020.0
# 491    tt12158538                                          Cry Havoc  2020.0
# 550     tt5761986                                        The Orchard  2020.0
# 841     tt8171000                                     Equal Standard  2020.0
# ...           ...                                                ...     ...
# 27983   tt1964995                                       Penance Lane  2020.0
# 28006   tt2573372                                           Becoming  2020.0
# 28126  tt11766318                                           Homeward  2020.0
# 28175  tt11127256                                              Choke  2020.0
# 28302   tt1634106                                          Bloodshot  2020.0
#
#       data_lancamento                       generos  duracao pais  \
# 238        2020-06-05    Biography, Drama, Thriller      107  USA
# 301        2020-02-06      Action, Adventure, Crime      109  USA
# 491        2020-05-05                        Horror       85  USA
# 550        2020-03-24       Crime, Horror, Thriller       81  USA
# 841        2020-05-14          Action, Crime, Drama      101  USA
# ...               ...                           ...      ...  ...
# 27983      2020-04-21                        Horror       84  USA
# 28006      2020-03-06         Drama, Horror, Sci-Fi       98  USA
# 28126      2020-02-25  Animation, Adventure, Family       81  USA
# 28175      2020-05-10              Horror, Thriller       73  USA
# 28302      2020-03-27         Action, Drama, Sci-Fi      109  USA
#
#                  idioma   orcamento      receita  receita_eua  nota_imdb  \
# 238             English         NaN      75911.0          NaN        6.2
# 301    English, Chinese  84500000.0  201858461.0   84158461.0        6.1
# 491             English   4000000.0          NaN          NaN        3.2
# 550             English   2500000.0          NaN          NaN        3.3
# 841             English         NaN          NaN          NaN        5.6
# ...                 ...         ...          ...          ...        ...
# 27983               NaN         NaN          NaN          NaN        4.8
# 28006           English         NaN      14285.0          NaN        4.6
# 28126           English         NaN          NaN          NaN        2.5
# 28175               NaN         NaN          NaN          NaN        5.7
# 28302  English, Persian  45000000.0   30855391.0   10021787.0        5.7
#
#        num_avaliacoes                direcao  \
# 238              4612       Josephine Decker
# 301            137373              Cathy Yan
# 491               136             Rene Perez
# 550               330        Michael Caissie
# 841               104  Brendan Kyle Cochrane
# ...               ...                    ...
# 27983             828           Péter Engert
# 28006             650              Omar Naim
# 28126             213        Michael Johnson
# 28175            2179       Gregory Hatanaka
# 28302           49627            Dave Wilson
#
#                                   roteiro                       producao  \
# 238    Sarah Gubbins, Susan Scarf Merrell  Los Angeles Media Fund (LAMF)
# 301           Christina Hodson, Paul Dini        Clubhouse Pictures (II)
# 491                            Rene Perez           Samera Entertainment
# 550                       Michael Caissie           BondIt Media Capital
# 841                          Taheim Bryan                  Digital Seven
# ...                                   ...                            ...
# 27983       Renae Geerlings, Matt Granger             Mane Entertainment
# 28006                           Omar Naim                 Traverse Media
# 28126    Aaron Witlin, David Michael Latt                     The Asylum
# 28175                    Gregory Hatanaka        CineRidge Entertainment
# 28302         Jeff Wadlow, Eric Heisserer              Columbia Pictures
#
#                                                   elenco  \
# 238    Elisabeth Moss, Odessa Young, Michael Stuhlbar...
# 301    Margot Robbie, Rosie Perez, Mary Elizabeth Win...
# 491    J.D. Angstadt, Robert Bronzi, Spring Inés Peña...
# 550    Katrina Bowden, Jay Mohr, Will Carlson, Spence...
# 841    Ice-T, Fredro Starr, Jules Willcox, Robert Clo...
# ...                                                  ...
# 27983  Tyler Mane, Scout Taylor-Compton, John Schneid...
# 28006  Toby Kebbell, Penelope Mitchell, Jeff Daniel P...
# 28126  Joey Lawrence, James Cullen Bressack, Kim Litt...
# 28175  Shane Ryan, Scott Butler, Sarah Brine, Lisa Lo...
# 28302  Vin Diesel, Eiza González, Sam Heughan, Toby K...
#
#                                                descricao  \
# 238    A famous horror writer finds inspiration for h...
# 301    After splitting with the Joker, Harley Quinn j...
# 491    A rogue police officer takes on a serial kille...
# 550    A sheriff makes a strange discovery when he ge...
# 841    New York City police officers lives collide in...
# ...                                                  ...
# 27983  A hardened criminal fresh out of the joint tak...
# 28006  A young woman learns her fiance has become pos...
# 28126  A boastful elf and his prank-happy orc brother...
# 28175  The lines between reality and fiction, and goo...
# 28302  Ray Garrison, a slain soldier, is re-animated ...
#
#        num_criticas_publico  num_criticas_critica
# 238                    75.0                  98.0
# 301                  2222.0                 372.0
# 491                     9.0                  23.0
# 550                    16.0                  11.0
# 841                    12.0                   NaN
# ...                     ...                   ...
# 27983                  33.0                  19.0
# 28006                  14.0                  15.0
# 28126                  13.0                   1.0
# 28175                  30.0                  21.0
# 28302                 672.0                 188.0
#
# [276 rows x 20 columns]
